# %%
import geopandas as gpd

fname = r"C:\Users\sheno\Downloads\export.geojson"


df1 = gpd.read_file(fname)

print(type(df1))

df1
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
#                     id                @id admin_level alt_name alt_name:mr  \
# 0     relation/9703976   relation/9703976           6      NaN         NaN
# 1     relation/9704036   relation/9704036           6      NaN         NaN
# 2     relation/9704181   relation/9704181           6      NaN         NaN
# 3     relation/9704321   relation/9704321           6      NaN         NaN
# 4     relation/9704525   relation/9704525           6      NaN         NaN
# ..                 ...                ...         ...      ...         ...
# 350  relation/10356053  relation/10356053           6      NaN         NaN
# 351  relation/10356203  relation/10356203           6      NaN         NaN
# 352  relation/10356204  relation/10356204           6      NaN         NaN
# 353  relation/10356205  relation/10356205           6      NaN         NaN
# 354  relation/10356363  relation/10356363           6      NaN         NaN
#
# ...

# %%
df1.drop( ['id', '@id','admin_level','alt_name','alt_name:mr','boundary','loc_name','name:ar','name:az-Arab','name:azb','name:de','name:el', 'name:en', 'name:es', 'name:fa', 'name:hi', 'name:hy','name:ks', 'name:mr', 'name:pa', 'name:pnb', 'name:ps', 'name:ru','name:sv', 'name:uk', 'name:ur', 'place', 'population', 'source','type', 'wikidata', 'wikipedia', 'wikipedia:ur', '@geometry'] , axis=1, inplace=True)

# %%
print(df1)
# Out:
#             name                   geometry
# 0      Shahuwadi  POINT (73.89486 16.96169)
# 1        Panhala  POINT (74.02139 16.76073)
# 2    Hatkanangle  POINT (74.35234 16.74560)
# 3         Shirol  POINT (74.57352 16.71143)
# 4       Kolhapur  POINT (74.18994 16.65949)
# ..           ...                        ...
# 350  Vaibhavwadi  POINT (73.77356 16.53203)
# 351     Khanapur  POINT (74.65244 17.29129)
# 352     Kadegaon  POINT (74.37414 17.27609)
# 353       Atpadi  POINT (74.86242 17.42712)
# 354     Sironcha  POINT (80.10556 18.91256)
#
# [355 rows x 2 columns]
